# %% [markdown]
# <a href="https://colab.research.google.com/github/PRADEEPSINHCHAVDA/DAA_hands-on/blob/main/bubblesort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def demo_bubble_sort(array):
    n = len(array)
    # Traverse through all array elements
    for i in range(n):
        # Last i elements are already in place
        for j in range(0, n-i-1):
            # Swap if the element found is greater than the next element
            if array[j] > array[j+1]:
                array[j], array[j+1] = array[j+1], array[j]

    return array

# This function takes input from the user
get_user_input = input("Please enter the array elements, separated by commas: ")
# This will convert input string to integers
array = list(map(int, get_user_input.split(',')))

# Function is used to sort the array
final_sorted_array = demo_bubble_sort(array)

# This function will print the sorted array
print("Final sorted array:", final_sorted_array)

def benchmark_demo_bubble_sort():
    input_arraysizes = [5, 10, 50, 100,500,5000,10000]#list of different list to sort
    execution_times = []

    for size in input_arraysizes:
        array = list(range(size, 0, -1))  # Descending order list for worst-case scenario
        time_taken = timeit.timeit(lambda: demo_bubble_sort(array.copy()), number=10) #measuring the time taken to sort
        execution_times.append(time_taken)

    # Plotting the results
    plt.figure(figsize=(10, 6))
    plt.plot(input_arraysizes, execution_times, label='Bubble Sort', marker='o', color='red')
    plt.xlabel('Input Size (n)')
    plt.ylabel('Execution Time (seconds)')
    plt.title('Pradeep_1002231638 Selection Sort Benchmark')
    plt.grid(True)
    plt.legend()
    plt.show()
#calling the benchmark function
benchmark_demo_bubble_sort()
# Out:
# Please enter the array elements, separated by commas: 8,88,74
# Final sorted array: [8, 74, 88]
